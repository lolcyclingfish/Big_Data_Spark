# %% [markdown]
# Plan:
# 1. extract year, district
# 2. filter and extract year and district columns from year 2001 - 2015
# 3. regular expression match all rows where year is 4-digit integers, district is 3-digit integers
# 3. create key, value pair: block, 1 (1 is to count the crime record once)
# 4. calculate count(crime) by {year,district}
# 5. split counts RDD into two seperate RDD based on years under Daley and Emanuel
# 6. map {district, number of crime} for two RDD
# 7. reduceByKey to get count(crime) by district for Delay and Emanuel
# 8. join Delay and Emanuel by district
# 9. create new field of difference between count(crime) of each district
# 10. perform student-t hyphothesis test on: Daley count - Emanuel count >0

# %%
#from pyspark import SparkContext
from pyspark import SparkContext
import csv
import re
from operator import add
from pyspark.mllib.stat import Statistics
import math
from scipy import stats
#from pyspark.sql import SQLContext
from geopy.geocoders import Nominatim

sc = SparkContext.getOrCreate()

# %%
#use when done with current pyspark context
sc.stop()

# %%
crimeFile = sc.textFile("Crimes_-_2001_to_present.csv")
crimeFile.take(5)
# Out:
# ['ID,Case Number,Date,Block,IUCR,Primary Type,Description,Location Description,Arrest,Domestic,Beat,District,Ward,Community Area,FBI Code,X Coordinate,Y Coordinate,Year,Updated On,Latitude,Longitude,Location',
#  '10078659,HY267429,05/19/2015 11:57:00 PM,010XX E 79TH ST,143A,WEAPONS VIOLATION,UNLAWFUL POSS OF HANDGUN,STREET,true,false,0624,006,8,44,15,1184626,1852799,2015,05/26/2015 12:42:06 PM,41.751242944,-87.599004724,"(41.751242944, -87.599004724)"',
#  '10078598,HY267408,05/19/2015 11:50:00 PM,067XX N SHERIDAN RD,3731,INTERFERENCE WITH PUBLIC OFFICER,OBSTRUCTING IDENTIFICATION,STREET,true,false,2432,024,49,1,24,1167071,1944859,2015,05/26/2015 12:42:06 PM,42.004255918,-87.660691083,"(42.004255918, -87.660691083)"',
#  '10078625,HY267417,05/19/2015 11:47:00 PM,026XX E 77TH ST,2170,NARCOTICS,POSSESSION OF DRUG EQUIPMENT,STREET,true,false,0421,004,7,43,18,1195299,1854463,2015,05/26/2015 12:42:06 PM,41.755552462,-87.559839339,"(41.755552462, -87.559839339)"',
#  '10078662,HY267423,05/19/2015 11:46:00 PM,015XX E 62ND ST,051A,ASSAULT,AGGRAVATED: HANDGUN,APARTMENT,false,true,0314,003,5,42,04A,1187377,1864316,2015,05/26/2015 12:42:06 PM,41.782781732,-87.588558362,"(41.782781732, -87.588558362)"']

# %%
schemaString=crimeFile.first()
schemaString
# Out:
# 'ID,Case Number,Date,Block,IUCR,Primary Type,Description,Location Description,Arrest,Domestic,Beat,District,Ward,Community Area,FBI Code,X Coordinate,Y Coordinate,Year,Updated On,Latitude,Longitude,Location'

# %%
#split by "," to create columns
fields = crimeFile.map(lambda line: line.split(","))
fields.count()
# Out:
# 5801845

# %%
(5801845-4438686)/5801845
# Out:
# 0.23495267453715155

# %%
#remove rows where columns 11: district, 18: year is empty
fields = fields.filter(lambda x: len(x[11])==3 and len(x[17])==4) 
fields.count()
#lose about 23.5% data
# Out:
# 4438686

# %%
fields.take(10)
# Out:
# [['10078659',
#   'HY267429',
#   '05/19/2015 11:57:00 PM',
#   '010XX E 79TH ST',
#   '143A',
#   'WEAPONS VIOLATION',
#   'UNLAWFUL POSS OF HANDGUN',
#   'STREET',
#   'true',
#   'false',
#   '0624',
#   '006',
#   '8',
#   '44',
#   '15',
#   '1184626',
#   '1852799',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.751242944',
#   '-87.599004724',
#   '"(41.751242944',
#   ' -87.599004724)"'],
#  ['10078598',
#   'HY267408',
#   '05/19/2015 11:50:00 PM',
#   '067XX N SHERIDAN RD',
#   '3731',
#   'INTERFERENCE WITH PUBLIC OFFICER',
#   'OBSTRUCTING IDENTIFICATION',
#   'STREET',
#   'true',
#   'false',
#   '2432',
#   '024',
#   '49',
#   '1',
#   '24',
#   '1167071',
#   '1944859',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '42.004255918',
#   '-87.660691083',
#   '"(42.004255918',
#   ' -87.660691083)"'],
#  ['10078625',
#   'HY267417',
#   '05/19/2015 11:47:00 PM',
#   '026XX E 77TH ST',
#   '2170',
#   'NARCOTICS',
#   'POSSESSION OF DRUG EQUIPMENT',
#   'STREET',
#   'true',
#   'false',
#   '0421',
#   '004',
#   '7',
#   '43',
#   '18',
#   '1195299',
#   '1854463',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.755552462',
#   '-87.559839339',
#   '"(41.755552462',
#   ' -87.559839339)"'],
#  ['10078662',
#   'HY267423',
#   '05/19/2015 11:46:00 PM',
#   '015XX E 62ND ST',
#   '051A',
#   'ASSAULT',
#   'AGGRAVATED: HANDGUN',
#   'APARTMENT',
#   'false',
#   'true',
#   '0314',
#   '003',
#   '5',
#   '42',
#   '04A',
#   '1187377',
#   '1864316',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.782781732',
#   '-87.588558362',
#   '"(41.782781732',
#   ' -87.588558362)"'],
#  ['10078584',
#   'HY267397',
#   '05/19/2015 11:45:00 PM',
#   '054XX S PRINCETON AVE',
#   '4625',
#   'OTHER OFFENSE',
#   'PAROLE VIOLATION',
#   'GAS STATION',
#   'true',
#   'false',
#   '0935',
#   '009',
#   '3',
#   '37',
#   '26',
#   '1175180',
#   '1868551',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.794684214',
#   '-87.633149481',
#   '"(41.794684214',
#   ' -87.633149481)"'],
#  ['10078629',
#   'HY267393',
#   '05/19/2015 11:40:00 PM',
#   '013XX S LAWNDALE AVE',
#   '0454',
#   'BATTERY',
#   'AGG PO HANDS NO/MIN INJURY',
#   'STREET',
#   'true',
#   'false',
#   '1011',
#   '010',
#   '24',
#   '29',
#   '08B',
#   '1151957',
#   '1893696',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.864172884',
#   '-87.717647622',
#   '"(41.864172884',
#   ' -87.717647622)"'],
#  ['10079225',
#   'HY267395',
#   '05/19/2015 11:30:00 PM',
#   '064XX S LAFLIN ST',
#   '0497',
#   'BATTERY',
#   'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON',
#   'APARTMENT',
#   'false',
#   'true',
#   '0725',
#   '007',
#   '17',
#   '67',
#   '04B',
#   '1167397',
#   '1862229',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.777506284',
#   '-87.661870632',
#   '"(41.777506284',
#   ' -87.661870632)"'],
#  ['10078594',
#   'HY267388',
#   '05/19/2015 11:30:00 PM',
#   '021XX W NORTH AVE',
#   '1305',
#   'CRIMINAL DAMAGE',
#   'CRIMINAL DEFACEMENT',
#   'SIDEWALK',
#   'true',
#   'false',
#   '1434',
#   '014',
#   '32',
#   '24',
#   '14',
#   '1162022',
#   '1910669',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.9105442',
#   '-87.680225036',
#   '"(41.9105442',
#   ' -87.680225036)"'],
#  ['10080768',
#   'HY269123',
#   '05/19/2015 11:30:00 PM',
#   '008XX N KILDARE AVE',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'RESIDENCE',
#   'false',
#   'false',
#   '1111',
#   '011',
#   '37',
#   '23',
#   '06',
#   '1147592',
#   '1905491',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.896624505',
#   '-87.733368852',
#   '"(41.896624505',
#   ' -87.733368852)"'],
#  ['10078618',
#   'HY267392',
#   '05/19/2015 11:30:00 PM',
#   '062XX S KOMENSKY AVE',
#   '0320',
#   'ROBBERY',
#   'STRONGARM - NO WEAPON',
#   'SIDEWALK',
#   'false',
#   'false',
#   '0813',
#   '008',
#   '13',
#   '65',
#   '03',
#   '1150396',
#   '1863112',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.780276746',
#   '-87.724174049',
#   '"(41.780276746',
#   ' -87.724174049)"']]

# %%
#use regular expression to filter and get rows with district - 3 digit number, year - 4 digit number
fields= fields.filter( lambda x: re.findall("[0-9]+", x[11]) and re.findall("[0-9]+", x[17]))
fields.count()

#test= fields.map( lambda x: re.findall("[0-9]+", x[11]) and re.findall("[0-9]+", x[18]))
#rdd.filter(lambda x:len(re.findall("[A-Za-z]+", x, 0)) > 1).map(lambda x: re.findall("[A-Za-z]+", x, 0)[1])
# Out:
# 4438686

# %%
fields.take(100)
# Out:
# [['10078659',
#   'HY267429',
#   '05/19/2015 11:57:00 PM',
#   '010XX E 79TH ST',
#   '143A',
#   'WEAPONS VIOLATION',
#   'UNLAWFUL POSS OF HANDGUN',
#   'STREET',
#   'true',
#   'false',
#   '0624',
#   '006',
#   '8',
#   '44',
#   '15',
#   '1184626',
#   '1852799',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.751242944',
#   '-87.599004724',
#   '"(41.751242944',
#   ' -87.599004724)"'],
#  ['10078598',
#   'HY267408',
#   '05/19/2015 11:50:00 PM',
#   '067XX N SHERIDAN RD',
#   '3731',
#   'INTERFERENCE WITH PUBLIC OFFICER',
#   'OBSTRUCTING IDENTIFICATION',
#   'STREET',
#   'true',
#   'false',
#   '2432',
#   '024',
#   '49',
#   '1',
#   '24',
#   '1167071',
#   '1944859',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '42.004255918',
#   '-87.660691083',
#   '"(42.004255918',
#   ' -87.660691083)"'],
#  ['10078625',
#   'HY267417',
#   '05/19/2015 11:47:00 PM',
#   '026XX E 77TH ST',
#   '2170',
#   'NARCOTICS',
#   'POSSESSION OF DRUG EQUIPMENT',
#   'STREET',
#   'true',
#   'false',
#   '0421',
#   '004',
#   '7',
#   '43',
#   '18',
#   '1195299',
#   '1854463',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.755552462',
#   '-87.559839339',
#   '"(41.755552462',
#   ' -87.559839339)"'],
#  ['10078662',
#   'HY267423',
#   '05/19/2015 11:46:00 PM',
#   '015XX E 62ND ST',
#   '051A',
#   'ASSAULT',
#   'AGGRAVATED: HANDGUN',
#   'APARTMENT',
#   'false',
#   'true',
#   '0314',
#   '003',
#   '5',
#   '42',
#   '04A',
#   '1187377',
#   '1864316',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.782781732',
#   '-87.588558362',
#   '"(41.782781732',
#   ' -87.588558362)"'],
#  ['10078584',
#   'HY267397',
#   '05/19/2015 11:45:00 PM',
#   '054XX S PRINCETON AVE',
#   '4625',
#   'OTHER OFFENSE',
#   'PAROLE VIOLATION',
#   'GAS STATION',
#   'true',
#   'false',
#   '0935',
#   '009',
#   '3',
#   '37',
#   '26',
#   '1175180',
#   '1868551',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.794684214',
#   '-87.633149481',
#   '"(41.794684214',
#   ' -87.633149481)"'],
#  ['10078629',
#   'HY267393',
#   '05/19/2015 11:40:00 PM',
#   '013XX S LAWNDALE AVE',
#   '0454',
#   'BATTERY',
#   'AGG PO HANDS NO/MIN INJURY',
#   'STREET',
#   'true',
#   'false',
#   '1011',
#   '010',
#   '24',
#   '29',
#   '08B',
#   '1151957',
#   '1893696',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.864172884',
#   '-87.717647622',
#   '"(41.864172884',
#   ' -87.717647622)"'],
#  ['10079225',
#   'HY267395',
#   '05/19/2015 11:30:00 PM',
#   '064XX S LAFLIN ST',
#   '0497',
#   'BATTERY',
#   'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON',
#   'APARTMENT',
#   'false',
#   'true',
#   '0725',
#   '007',
#   '17',
#   '67',
#   '04B',
#   '1167397',
#   '1862229',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.777506284',
#   '-87.661870632',
#   '"(41.777506284',
#   ' -87.661870632)"'],
#  ['10078594',
#   'HY267388',
#   '05/19/2015 11:30:00 PM',
#   '021XX W NORTH AVE',
#   '1305',
#   'CRIMINAL DAMAGE',
#   'CRIMINAL DEFACEMENT',
#   'SIDEWALK',
#   'true',
#   'false',
#   '1434',
#   '014',
#   '32',
#   '24',
#   '14',
#   '1162022',
#   '1910669',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.9105442',
#   '-87.680225036',
#   '"(41.9105442',
#   ' -87.680225036)"'],
#  ['10080768',
#   'HY269123',
#   '05/19/2015 11:30:00 PM',
#   '008XX N KILDARE AVE',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'RESIDENCE',
#   'false',
#   'false',
#   '1111',
#   '011',
#   '37',
#   '23',
#   '06',
#   '1147592',
#   '1905491',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.896624505',
#   '-87.733368852',
#   '"(41.896624505',
#   ' -87.733368852)"'],
#  ['10078618',
#   'HY267392',
#   '05/19/2015 11:30:00 PM',
#   '062XX S KOMENSKY AVE',
#   '0320',
#   'ROBBERY',
#   'STRONGARM - NO WEAPON',
#   'SIDEWALK',
#   'false',
#   'false',
#   '0813',
#   '008',
#   '13',
#   '65',
#   '03',
#   '1150396',
#   '1863112',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.780276746',
#   '-87.724174049',
#   '"(41.780276746',
#   ' -87.724174049)"'],
#  ['10079167',
#   'HY267537',
#   '05/19/2015 11:30:00 PM',
#   '054XX N LIEB AVE',
#   '0910',
#   'MOTOR VEHICLE THEFT',
#   'AUTOMOBILE',
#   'STREET',
#   'false',
#   'false',
#   '1623',
#   '016',
#   '45',
#   '11',
#   '07',
#   '1140177',
#   '1935703',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.979668326',
#   '-87.759860921',
#   '"(41.979668326',
#   ' -87.759860921)"'],
#  ['10078585',
#   'HY267389',
#   '05/19/2015 11:25:00 PM',
#   '0000X N KILBOURN AVE',
#   '2027',
#   'NARCOTICS',
#   'POSS: CRACK',
#   'SIDEWALK',
#   'true',
#   'false',
#   '1113',
#   '011',
#   '28',
#   '26',
#   '18',
#   '1146345',
#   '1899833',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.88112215',
#   '-87.738093068',
#   '"(41.88112215',
#   ' -87.738093068)"'],
#  ['10078582',
#   'HY267385',
#   '05/19/2015 11:25:00 PM',
#   '0000X N MAYFIELD AVE',
#   '1365',
#   'CRIMINAL TRESPASS',
#   'TO RESIDENCE',
#   'APARTMENT',
#   'true',
#   'false',
#   '1513',
#   '015',
#   '29',
#   '25',
#   '26',
#   '1137200',
#   '1899751',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.881066275',
#   '-87.771675422',
#   '"(41.881066275',
#   ' -87.771675422)"'],
#  ['10078652',
#   'HY267402',
#   '05/19/2015 11:20:00 PM',
#   '073XX N SHERIDAN RD',
#   '0320',
#   'ROBBERY',
#   'STRONGARM - NO WEAPON',
#   'STREET',
#   'false',
#   'false',
#   '2423',
#   '024',
#   '49',
#   '1',
#   '03',
#   '1165934',
#   '1948944',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '42.015489661',
#   '-87.66475673',
#   '"(42.015489661',
#   ' -87.66475673)"'],
#  ['10078660',
#   'HY267382',
#   '05/19/2015 11:15:00 PM',
#   '049XX W CONGRESS PKWY',
#   '1310',
#   'CRIMINAL DAMAGE',
#   'TO PROPERTY',
#   'RESIDENCE',
#   'false',
#   'false',
#   '1533',
#   '015',
#   '24',
#   '25',
#   '14',
#   '1143817',
#   '1897274',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.874147678',
#   '-87.747439984',
#   '"(41.874147678',
#   ' -87.747439984)"'],
#  ['10078623',
#   'HY267391',
#   '05/19/2015 11:15:00 PM',
#   '043XX W CULLERTON ST',
#   '051A',
#   'ASSAULT',
#   'AGGRAVATED: HANDGUN',
#   'SIDEWALK',
#   'false',
#   'false',
#   '1012',
#   '010',
#   '24',
#   '29',
#   '04A',
#   '1147707',
#   '1890105',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.854401311',
#   '-87.733341502',
#   '"(41.854401311',
#   ' -87.733341502)"'],
#  ['10078579',
#   'HY267390',
#   '05/19/2015 11:13:00 PM',
#   '056XX W CORCORAN PL',
#   '2024',
#   'NARCOTICS',
#   'POSS: HEROIN(WHITE)',
#   'ALLEY',
#   'true',
#   'false',
#   '1512',
#   '015',
#   '29',
#   '25',
#   '18',
#   '1138870',
#   '1901963',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.887106133',
#   '-87.765489447',
#   '"(41.887106133',
#   ' -87.765489447)"'],
#  ['10078628',
#   'HY267380',
#   '05/19/2015 11:10:00 PM',
#   '087XX S WABASH AVE',
#   '041A',
#   'BATTERY',
#   'AGGRAVATED: HANDGUN',
#   'STREET',
#   'false',
#   'false',
#   '0632',
#   '006',
#   '6',
#   '44',
#   '04B',
#   '1178206',
#   '1846803',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.734937154',
#   '-87.622712115',
#   '"(41.734937154',
#   ' -87.622712115)"'],
#  ['10078636',
#   'HY267384',
#   '05/19/2015 11:09:00 PM',
#   '010XX W MARQUETTE RD',
#   '0496',
#   'BATTERY',
#   'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST',
#   'RESIDENCE',
#   'true',
#   'true',
#   '0724',
#   '007',
#   '17',
#   '68',
#   '04B',
#   '1170665',
#   '1860353',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.772287667',
#   '-87.649944792',
#   '"(41.772287667',
#   ' -87.649944792)"'],
#  ['10078602',
#   'HY267373',
#   '05/19/2015 11:08:00 PM',
#   '016XX W 79TH ST',
#   '0460',
#   'BATTERY',
#   'SIMPLE',
#   'SIDEWALK',
#   'true',
#   'false',
#   '0611',
#   '006',
#   '17',
#   '71',
#   '08B',
#   '1167028',
#   '1852372',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.750465259',
#   '-87.663504783',
#   '"(41.750465259',
#   ' -87.663504783)"'],
#  ['10078563',
#   'HY267381',
#   '05/19/2015 11:08:00 PM',
#   '007XX W 111TH ST',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'STREET',
#   'true',
#   'false',
#   '2233',
#   '022',
#   '34',
#   '49',
#   '18',
#   '1173240',
#   '1831288',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.692472823',
#   '-87.641362189',
#   '"(41.692472823',
#   ' -87.641362189)"'],
#  ['10078595',
#   'HY267400',
#   '05/19/2015 11:08:00 PM',
#   '083XX S CALIFORNIA AVE',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'STREET',
#   'true',
#   'false',
#   '0835',
#   '008',
#   '18',
#   '70',
#   '18',
#   '1159123',
#   '1849119',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.741703738',
#   '-87.692561307',
#   '"(41.741703738',
#   ' -87.692561307)"'],
#  ['10078572',
#   'HY267387',
#   '05/19/2015 11:06:00 PM',
#   '112XX S STATE ST',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'STREET',
#   'true',
#   'false',
#   '0522',
#   '005',
#   '34',
#   '49',
#   '18',
#   '1178207',
#   '1830675',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.690679727',
#   '-87.623195763',
#   '"(41.690679727',
#   ' -87.623195763)"'],
#  ['10078604',
#   'HY267374',
#   '05/19/2015 11:06:00 PM',
#   '014XX N RIDGEWAY AVE',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'RESIDENCE',
#   'true',
#   'false',
#   '2535',
#   '025',
#   '26',
#   '23',
#   '08B',
#   '1151137',
#   '1909629',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.907910818',
#   '-87.720239958',
#   '"(41.907910818',
#   ' -87.720239958)"'],
#  ['10078821',
#   'HY267573',
#   '05/19/2015 11:00:00 PM',
#   '013XX W BERWYN AVE',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'STREET',
#   'false',
#   'false',
#   '2013',
#   '020',
#   '48',
#   '77',
#   '06',
#   '1166149',
#   '1935272',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.977968777',
#   '-87.664358639',
#   '"(41.977968777',
#   ' -87.664358639)"'],
#  ['10078610',
#   'HY267401',
#   '05/19/2015 11:00:00 PM',
#   '078XX S SOUTH SHORE DR',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'RESIDENCE',
#   'true',
#   'true',
#   '0421',
#   '004',
#   '7',
#   '46',
#   '08B',
#   '1198252',
#   '1853469',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.752751493',
#   '-87.54905078',
#   '"(41.752751493',
#   ' -87.54905078)"'],
#  ['10078816',
#   'HY267500',
#   '05/19/2015 11:00:00 PM',
#   '004XX S CLARK ST',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'STREET',
#   'false',
#   'false',
#   '0122',
#   '001',
#   '2',
#   '32',
#   '06',
#   '1175557',
#   '1898269',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.876224374',
#   '-87.630875853',
#   '"(41.876224374',
#   ' -87.630875853)"'],
#  ['10079125',
#   'HY267703',
#   '05/19/2015 11:00:00 PM',
#   '003XX W HURON ST',
#   '0620',
#   'BURGLARY',
#   'UNLAWFUL ENTRY',
#   'RESTAURANT',
#   'false',
#   'false',
#   '1831',
#   '018',
#   '42',
#   '8',
#   '05',
#   '1173905',
#   '1904969',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.894646518',
#   '-87.636741685',
#   '"(41.894646518',
#   ' -87.636741685)"'],
#  ['10078878',
#   'HY267570',
#   '05/19/2015 11:00:00 PM',
#   '024XX W BELLE PLAINE AVE',
#   '1305',
#   'CRIMINAL DAMAGE',
#   'CRIMINAL DEFACEMENT',
#   'RESIDENCE',
#   'false',
#   'false',
#   '1911',
#   '019',
#   '47',
#   '5',
#   '14',
#   '1159574',
#   '1927119',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.955734892',
#   '-87.688763744',
#   '"(41.955734892',
#   ' -87.688763744)"'],
#  ['10078889',
#   'HY267562',
#   '05/19/2015 11:00:00 PM',
#   '067XX S WOOD ST',
#   '1310',
#   'CRIMINAL DAMAGE',
#   'TO PROPERTY',
#   'RESIDENCE',
#   'false',
#   'false',
#   '0726',
#   '007',
#   '15',
#   '67',
#   '14',
#   '1165477',
#   '1859714',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.770645716',
#   '-87.668980598',
#   '"(41.770645716',
#   ' -87.668980598)"'],
#  ['10078649',
#   'HY267383',
#   '05/19/2015 10:57:00 PM',
#   '017XX W HOWARD ST',
#   '0860',
#   'THEFT',
#   'RETAIL THEFT',
#   'GROCERY FOOD STORE',
#   'false',
#   'false',
#   '2422',
#   '024',
#   '49',
#   '1',
#   '06',
#   '1163125',
#   '1950307',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '42.019289497',
#   '-87.675054297',
#   '"(42.019289497',
#   ' -87.675054297)"'],
#  ['10078568',
#   'HY267375',
#   '05/19/2015 10:55:00 PM',
#   '061XX S ARTESIAN AVE',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'STREET',
#   'true',
#   'false',
#   '0825',
#   '008',
#   '15',
#   '66',
#   '18',
#   '1161061',
#   '1863544',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.781248237',
#   '-87.685062191',
#   '"(41.781248237',
#   ' -87.685062191)"'],
#  ['10078605',
#   'HY267386',
#   '05/19/2015 10:50:00 PM',
#   '095XX S INDIANA AVE',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'RESIDENCE',
#   'false',
#   'true',
#   '0511',
#   '005',
#   '6',
#   '49',
#   '08B',
#   '1179224',
#   '1841722',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.720971129',
#   '-87.619137064',
#   '"(41.720971129',
#   ' -87.619137064)"'],
#  ['10078554',
#   'HY267365',
#   '05/19/2015 10:50:00 PM',
#   '052XX S ST LOUIS AVE',
#   '2022',
#   'NARCOTICS',
#   'POSS: COCAINE',
#   'STREET',
#   'true',
#   'false',
#   '0822',
#   '008',
#   '14',
#   '63',
#   '18',
#   '1153975',
#   '1869616',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.798054356',
#   '-87.710880073',
#   '"(41.798054356',
#   ' -87.710880073)"'],
#  ['10079060',
#   'HY267771',
#   '05/19/2015 10:40:00 PM',
#   '006XX S STATE ST',
#   '0810',
#   'THEFT',
#   'OVER $500',
#   'CTA BUS STOP',
#   'false',
#   'false',
#   '0123',
#   '001',
#   '2',
#   '32',
#   '06',
#   '1176412',
#   '1897633',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.874459907',
#   '-87.627755816',
#   '"(41.874459907',
#   ' -87.627755816)"'],
#  ['10078635',
#   'HY267360',
#   '05/19/2015 10:40:00 PM',
#   '064XX S LAFLIN ST',
#   '1310',
#   'CRIMINAL DAMAGE',
#   'TO PROPERTY',
#   'RESIDENCE',
#   'false',
#   'false',
#   '0725',
#   '007',
#   '17',
#   '67',
#   '14',
#   '1167485',
#   '1861938',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.776705857',
#   '-87.661556357',
#   '"(41.776705857',
#   ' -87.661556357)"'],
#  ['10078626',
#   'HY267359',
#   '05/19/2015 10:34:00 PM',
#   '048XX S DREXEL BLVD',
#   '041A',
#   'BATTERY',
#   'AGGRAVATED: HANDGUN',
#   'SIDEWALK',
#   'false',
#   'false',
#   '0223',
#   '002',
#   '4',
#   '39',
#   '04B',
#   '1182965',
#   '1873014',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.806753504',
#   '-87.60446352',
#   '"(41.806753504',
#   ' -87.60446352)"'],
#  ['10078599',
#   'HY267356',
#   '05/19/2015 10:33:00 PM',
#   '006XX N TROY ST',
#   '143A',
#   'WEAPONS VIOLATION',
#   'UNLAWFUL POSS OF HANDGUN',
#   'RESIDENTIAL YARD (FRONT/BACK)',
#   'true',
#   'false',
#   '1221',
#   '012',
#   '27',
#   '23',
#   '15',
#   '1155222',
#   '1904077',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.892594523',
#   '-87.705383025',
#   '"(41.892594523',
#   ' -87.705383025)"'],
#  ['10080075',
#   'HY267366',
#   '05/19/2015 10:30:00 PM',
#   '054XX S HARPER AVE',
#   '1310',
#   'CRIMINAL DAMAGE',
#   'TO PROPERTY',
#   'STREET',
#   'false',
#   'false',
#   '0234',
#   '002',
#   '4',
#   '41',
#   '14',
#   '1187237',
#   '1869686',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.797520751',
#   '-87.588901162',
#   '"(41.797520751',
#   ' -87.588901162)"'],
#  ['10078643',
#   'HY267344',
#   '05/19/2015 10:30:00 PM',
#   '065XX S LOWE AVE',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'APARTMENT',
#   'false',
#   'true',
#   '0723',
#   '007',
#   '20',
#   '68',
#   '08B',
#   '1173205',
#   '1861446',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.775231224',
#   '-87.640601652',
#   '"(41.775231224',
#   ' -87.640601652)"'],
#  ['10079228',
#   'HY267845',
#   '05/19/2015 10:30:00 PM',
#   '035XX N HAMLIN AVE',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'STREET',
#   'false',
#   'false',
#   '1732',
#   '017',
#   '30',
#   '21',
#   '06',
#   '1150462',
#   '1923575',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.946193068',
#   '-87.722354527',
#   '"(41.946193068',
#   ' -87.722354527)"'],
#  ['10078596',
#   'HY267406',
#   '05/19/2015 10:30:00 PM',
#   '042XX W AUGUSTA BLVD',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'SIDEWALK',
#   'false',
#   'true',
#   '1111',
#   '011',
#   '37',
#   '23',
#   '08B',
#   '1147727',
#   '1906284',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.89879799',
#   '-87.73285263',
#   '"(41.89879799',
#   ' -87.73285263)"'],
#  ['10078686',
#   'HY267426',
#   '05/19/2015 10:30:00 PM',
#   '066XX S MARQUETTE RD',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'APARTMENT',
#   'false',
#   'false',
#   '0312',
#   '003',
#   '20',
#   '42',
#   '06',
#   '1180673',
#   '1861203',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.774396071',
#   '-87.613232572',
#   '"(41.774396071',
#   ' -87.613232572)"'],
#  ['10078533',
#   'HY267345',
#   '05/19/2015 10:30:00 PM',
#   '113XX S NORMAL AVE',
#   '1310',
#   'CRIMINAL DAMAGE',
#   'TO PROPERTY',
#   'RESIDENCE',
#   'false',
#   'false',
#   '2233',
#   '022',
#   '34',
#   '49',
#   '14',
#   '1174952',
#   '1829699',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.688074453',
#   '-87.635141443',
#   '"(41.688074453',
#   ' -87.635141443)"'],
#  ['10079932',
#   'HY268586',
#   '05/19/2015 10:28:00 PM',
#   '013XX N CENTRAL AVE',
#   '0420',
#   'BATTERY',
#   'AGGRAVATED:KNIFE/CUTTING INSTR',
#   'SIDEWALK',
#   'false',
#   'false',
#   '2531',
#   '025',
#   '29',
#   '25',
#   '04B',
#   '1138726',
#   '1908133',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.904039989',
#   '-87.765868403',
#   '"(41.904039989',
#   ' -87.765868403)"'],
#  ['10078583',
#   'HY267357',
#   '05/19/2015 10:27:00 PM',
#   '014XX W MONTROSE AVE',
#   '0630',
#   'BURGLARY',
#   'ATTEMPT FORCIBLE ENTRY',
#   'RESIDENCE-GARAGE',
#   'false',
#   'false',
#   '1912',
#   '019',
#   '47',
#   '3',
#   '05',
#   '1165388',
#   '1929347',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.961726632',
#   '-87.667326589',
#   '"(41.961726632',
#   ' -87.667326589)"'],
#  ['10078551',
#   'HY267337',
#   '05/19/2015 10:20:00 PM',
#   '025XX N LOWELL AVE',
#   '051A',
#   'ASSAULT',
#   'AGGRAVATED: HANDGUN',
#   'SIDEWALK',
#   'false',
#   'false',
#   '2524',
#   '025',
#   '31',
#   '20',
#   '04A',
#   '1146914',
#   '1916621',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.927179332',
#   '-87.735574156',
#   '"(41.927179332',
#   ' -87.735574156)"'],
#  ['10081156',
#   'HY269498',
#   '05/19/2015 10:18:00 PM',
#   '002XX N COLUMBUS DR',
#   '0860',
#   'THEFT',
#   'RETAIL THEFT',
#   'SMALL RETAIL STORE',
#   'false',
#   'false',
#   '0114',
#   '001',
#   '42',
#   '32',
#   '06',
#   '1178261',
#   '1901979',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.886343653',
#   '-87.620834719',
#   '"(41.886343653',
#   ' -87.620834719)"'],
#  ['10078543',
#   'HY267330',
#   '05/19/2015 10:15:00 PM',
#   '014XX N HARDING AVE',
#   '0560',
#   'ASSAULT',
#   'SIMPLE',
#   'STREET',
#   'false',
#   'true',
#   '2535',
#   '025',
#   '30',
#   '23',
#   '08A',
#   '1149824',
#   '1909330',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.907115984',
#   '-87.725071057',
#   '"(41.907115984',
#   ' -87.725071057)"'],
#  ['10078609',
#   'HY267355',
#   '05/19/2015 10:14:00 PM',
#   '006XX N MC CLURG CT',
#   '0860',
#   'THEFT',
#   'RETAIL THEFT',
#   'SMALL RETAIL STORE',
#   'true',
#   'false',
#   '1834',
#   '018',
#   '42',
#   '8',
#   '06',
#   '1179050',
#   '1904309',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.892719269',
#   '-87.617866019',
#   '"(41.892719269',
#   ' -87.617866019)"'],
#  ['10078574',
#   'HY267349',
#   '05/19/2015 10:11:00 PM',
#   '029XX N KENOSHA AVE',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'STREET',
#   'true',
#   'false',
#   '2523',
#   '025',
#   '31',
#   '20',
#   '18',
#   '1147399',
#   '1919411',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.934826054',
#   '-87.73372027',
#   '"(41.934826054',
#   ' -87.73372027)"'],
#  ['10078566',
#   'HY267340',
#   '05/19/2015 10:09:00 PM',
#   '034XX W ROOSEVELT RD',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'STREET',
#   'true',
#   'false',
#   '1133',
#   '011',
#   '24',
#   '29',
#   '18',
#   '1153764',
#   '1894540',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.866453161',
#   '-87.710991681',
#   '"(41.866453161',
#   ' -87.710991681)"'],
#  ['10079547',
#   'HY268030',
#   '05/19/2015 10:00:00 PM',
#   '067XX S OAKLEY AVE',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'STREET',
#   'false',
#   'false',
#   '0832',
#   '008',
#   '17',
#   '66',
#   '06',
#   '1162183',
#   '1860113',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.771809816',
#   '-87.681044086',
#   '"(41.771809816',
#   ' -87.681044086)"'],
#  ['10078615',
#   'HY267323',
#   '05/19/2015 10:00:00 PM',
#   '031XX W 55TH ST',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'ALLEY',
#   'false',
#   'true',
#   '0923',
#   '009',
#   '14',
#   '63',
#   '08B',
#   '1156017',
#   '1868017',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.793625656',
#   '-87.703434597',
#   '"(41.793625656',
#   ' -87.703434597)"'],
#  ['10078976',
#   'HY267563',
#   '05/19/2015 10:00:00 PM',
#   '018XX W HOOD AVE',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'RESIDENCE-GARAGE',
#   'false',
#   'false',
#   '2413',
#   '024',
#   '40',
#   '2',
#   '06',
#   '1162982',
#   '1940741',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.993043178',
#   '-87.675850856',
#   '"(41.993043178',
#   ' -87.675850856)"'],
#  ['10079537',
#   'HY268016',
#   '05/19/2015 10:00:00 PM',
#   '038XX N KENMORE AVE',
#   '0910',
#   'MOTOR VEHICLE THEFT',
#   'AUTOMOBILE',
#   'STREET',
#   'false',
#   'false',
#   '1923',
#   '019',
#   '44',
#   '6',
#   '07',
#   '1168620',
#   '1925936',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.952297175',
#   '-87.655543182',
#   '"(41.952297175',
#   ' -87.655543182)"'],
#  ['10080085',
#   'HY268561',
#   '05/19/2015 10:00:00 PM',
#   '079XX S RIDGELAND AVE',
#   '0910',
#   'MOTOR VEHICLE THEFT',
#   'AUTOMOBILE',
#   'STREET',
#   'false',
#   'false',
#   '0414',
#   '004',
#   '8',
#   '46',
#   '07',
#   '1189318',
#   '1852767',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.751043957',
#   '-87.581812135',
#   '"(41.751043957',
#   ' -87.581812135)"'],
#  ['10078519',
#   'HY267315',
#   '05/19/2015 10:00:00 PM',
#   '116XX S BISHOP ST',
#   '2820',
#   'OTHER OFFENSE',
#   'TELEPHONE THREAT',
#   'RESIDENCE',
#   'false',
#   'true',
#   '0524',
#   '005',
#   '34',
#   '53',
#   '26',
#   '1168713',
#   '1827716',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.682769259',
#   '-87.658038816',
#   '"(41.682769259',
#   ' -87.658038816)"'],
#  ['10078860',
#   'HY267576',
#   '05/19/2015 10:00:00 PM',
#   '027XX W POLK ST',
#   '5002',
#   'OTHER OFFENSE',
#   'OTHER VEHICLE OFFENSE',
#   'RESIDENCE-GARAGE',
#   'false',
#   'false',
#   '1135',
#   '011',
#   '28',
#   '27',
#   '26',
#   '1158282',
#   '1896219',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.870969429',
#   '-87.694359719',
#   '"(41.870969429',
#   ' -87.694359719)"'],
#  ['10078744',
#   'HY267499',
#   '05/19/2015 10:00:00 PM',
#   '033XX W WARREN BLVD',
#   '2820',
#   'OTHER OFFENSE',
#   'TELEPHONE THREAT',
#   'RESIDENCE',
#   'false',
#   'true',
#   '1123',
#   '011',
#   '28',
#   '27',
#   '26',
#   '1154047',
#   '1900186',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.881940748',
#   '-87.709802183',
#   '"(41.881940748',
#   ' -87.709802183)"'],
#  ['10079231',
#   'HY267852',
#   '05/19/2015 10:00:00 PM',
#   '070XX S CONSTANCE AVE',
#   '0810',
#   'THEFT',
#   'OVER $500',
#   'STREET',
#   'false',
#   'false',
#   '0332',
#   '003',
#   '5',
#   '43',
#   '06',
#   '1189792',
#   '1858877',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.767798948',
#   '-87.579879089',
#   '"(41.767798948',
#   ' -87.579879089)"'],
#  ['10078611',
#   'HY267338',
#   '05/19/2015 10:00:00 PM',
#   '075XX S PRAIRIE AVE',
#   '0530',
#   'ASSAULT',
#   'AGGRAVATED: OTHER DANG WEAPON',
#   'APARTMENT',
#   'true',
#   'false',
#   '0623',
#   '006',
#   '6',
#   '69',
#   '04A',
#   '1179378',
#   '1855243',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.758070856',
#   '-87.618161437',
#   '"(41.758070856',
#   ' -87.618161437)"'],
#  ['10079129',
#   'HY267710',
#   '05/19/2015 10:00:00 PM',
#   '014XX W LUNT AVE',
#   '1320',
#   'CRIMINAL DAMAGE',
#   'TO VEHICLE',
#   'STREET',
#   'false',
#   'false',
#   '2423',
#   '024',
#   '49',
#   '1',
#   '14',
#   '1165161',
#   '1946646',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '42.009200443',
#   '-87.667666851',
#   '"(42.009200443',
#   ' -87.667666851)"'],
#  ['10079296',
#   'HY267860',
#   '05/19/2015 10:00:00 PM',
#   '034XX N LAVERGNE AVE',
#   '0810',
#   'THEFT',
#   'OVER $500',
#   'DRIVEWAY - RESIDENTIAL',
#   'false',
#   'false',
#   '1634',
#   '016',
#   '38',
#   '15',
#   '06',
#   '1142391',
#   '1922256',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.942727647',
#   '-87.752054088',
#   '"(41.942727647',
#   ' -87.752054088)"'],
#  ['10078520',
#   'HY267320',
#   '05/19/2015 09:50:00 PM',
#   '026XX W CRYSTAL ST',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'RESIDENCE PORCH/HALLWAY',
#   'true',
#   'false',
#   '1423',
#   '014',
#   '26',
#   '24',
#   '18',
#   '1158257',
#   '1908177',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.903783784',
#   '-87.694124475',
#   '"(41.903783784',
#   ' -87.694124475)"'],
#  ['10078620',
#   'HY267325',
#   '05/19/2015 09:48:00 PM',
#   '029XX W 63RD ST',
#   '031A',
#   'ROBBERY',
#   'ARMED: HANDGUN',
#   'RESTAURANT',
#   'false',
#   'false',
#   '0823',
#   '008',
#   '15',
#   '66',
#   '03',
#   '1157559',
#   '1862757',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.779160328',
#   '-87.697922699',
#   '"(41.779160328',
#   ' -87.697922699)"'],
#  ['10079820',
#   'HY268080',
#   '05/19/2015 09:45:00 PM',
#   '022XX N MC VICKER AVE',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'STREET',
#   'false',
#   'false',
#   '2512',
#   '025',
#   '37',
#   '19',
#   '06',
#   '1135733',
#   '1914528',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.921642443',
#   '-87.776710181',
#   '"(41.921642443',
#   ' -87.776710181)"'],
#  ['10078692',
#   'HY267307',
#   '05/19/2015 09:45:00 PM',
#   '070XX S RACINE AVE',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'SIDEWALK',
#   'false',
#   'true',
#   '0733',
#   '007',
#   '17',
#   '68',
#   '08B',
#   '1169573',
#   '1858251',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.766543256',
#   '-87.6540086',
#   '"(41.766543256',
#   ' -87.6540086)"'],
#  ['10078546',
#   'HY267332',
#   '05/19/2015 09:39:00 PM',
#   '002XX E ONTARIO ST',
#   '0610',
#   'BURGLARY',
#   'FORCIBLE ENTRY',
#   'OTHER',
#   'false',
#   'false',
#   '1834',
#   '018',
#   '42',
#   '8',
#   '05',
#   '1178033',
#   '1904501',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.893269336',
#   '-87.621595159',
#   '"(41.893269336',
#   ' -87.621595159)"'],
#  ['10078501',
#   'HY267303',
#   '05/19/2015 09:30:00 PM',
#   '015XX W PERSHING RD',
#   '0460',
#   'BATTERY',
#   'SIMPLE',
#   'SPORTS ARENA/STADIUM',
#   'true',
#   'false',
#   '0924',
#   '009',
#   '11',
#   '61',
#   '08B',
#   '1166473',
#   '1878818',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.82304819',
#   '-87.664785017',
#   '"(41.82304819',
#   ' -87.664785017)"'],
#  ['10078607',
#   'HY267405',
#   '05/19/2015 09:30:00 PM',
#   '073XX W HOWARD ST',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'RESIDENCE',
#   'false',
#   'true',
#   '1611',
#   '016',
#   '41',
#   '9',
#   '08B',
#   '1126638',
#   '1949874',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '42.01879281',
#   '-87.80933397',
#   '"(42.01879281',
#   ' -87.80933397)"'],
#  ['10079628',
#   'HY268142',
#   '05/19/2015 09:30:00 PM',
#   '065XX S TROY ST',
#   '0910',
#   'MOTOR VEHICLE THEFT',
#   'AUTOMOBILE',
#   'STREET',
#   'false',
#   'false',
#   '0831',
#   '008',
#   '15',
#   '66',
#   '07',
#   '1156553',
#   '1861071',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.774554033',
#   '-87.701656228',
#   '"(41.774554033',
#   ' -87.701656228)"'],
#  ['10078909',
#   'HY267577',
#   '05/19/2015 09:30:00 PM',
#   '048XX S CALUMET AVE',
#   '1320',
#   'CRIMINAL DAMAGE',
#   'TO VEHICLE',
#   'STREET',
#   'false',
#   'false',
#   '0224',
#   '002',
#   '3',
#   '38',
#   '14',
#   '1179205',
#   '1873183',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.807303928',
#   '-87.618248679',
#   '"(41.807303928',
#   ' -87.618248679)"'],
#  ['10078621',
#   'HY267367',
#   '05/19/2015 09:30:00 PM',
#   '051XX S DAMEN AVE',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'RESIDENCE',
#   'false',
#   'false',
#   '0932',
#   '009',
#   '16',
#   '61',
#   '06',
#   '1163861',
#   '1870201',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.799457506',
#   '-87.674609742',
#   '"(41.799457506',
#   ' -87.674609742)"'],
#  ['10078506',
#   'HY267304',
#   '05/19/2015 09:25:00 PM',
#   '012XX E 80TH ST',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'SIDEWALK',
#   'true',
#   'false',
#   '0411',
#   '004',
#   '8',
#   '45',
#   '18',
#   '1186151',
#   '1852248',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.749695094',
#   '-87.593433786',
#   '"(41.749695094',
#   ' -87.593433786)"'],
#  ['10078603',
#   'HY267291',
#   '05/19/2015 09:23:00 PM',
#   '075XX S MAY ST',
#   '031A',
#   'ROBBERY',
#   'ARMED: HANDGUN',
#   'GROCERY FOOD STORE',
#   'false',
#   'false',
#   '0612',
#   '006',
#   '17',
#   '71',
#   '03',
#   '1169927',
#   '1854496',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.756231373',
#   '-87.652819939',
#   '"(41.756231373',
#   ' -87.652819939)"'],
#  ['10078608',
#   'HY267306',
#   '05/19/2015 09:23:00 PM',
#   '075XX S MAY ST',
#   '1025',
#   'ARSON',
#   'AGGRAVATED',
#   'GROCERY FOOD STORE',
#   'false',
#   'false',
#   '0612',
#   '006',
#   '17',
#   '71',
#   '09',
#   '1169927',
#   '1854496',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.756231373',
#   '-87.652819939',
#   '"(41.756231373',
#   ' -87.652819939)"'],
#  ['10078558',
#   'HY267312',
#   '05/19/2015 09:20:00 PM',
#   '102XX S WENTWORTH AVE',
#   '1310',
#   'CRIMINAL DAMAGE',
#   'TO PROPERTY',
#   'RESIDENCE',
#   'false',
#   'false',
#   '0511',
#   '005',
#   '9',
#   '49',
#   '14',
#   '1176705',
#   '1837173',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.708545025',
#   '-87.628499967',
#   '"(41.708545025',
#   ' -87.628499967)"'],
#  ['10078541',
#   'HY267276',
#   '05/19/2015 09:19:00 PM',
#   '055XX W NORTH AVE',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'STREET',
#   'true',
#   'false',
#   '2532',
#   '025',
#   '37',
#   '25',
#   '18',
#   '1139247',
#   '1910129',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.909507774',
#   '-87.763905938',
#   '"(41.909507774',
#   ' -87.763905938)"'],
#  ['10078517',
#   'HY267321',
#   '05/19/2015 09:15:00 PM',
#   '058XX N WASHTENAW AVE',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'STREET',
#   'false',
#   'false',
#   '2011',
#   '020',
#   '40',
#   '2',
#   '06',
#   '1157322',
#   '1938736',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.987658728',
#   '-87.69672526',
#   '"(41.987658728',
#   ' -87.69672526)"'],
#  ['10078955',
#   'HY267670',
#   '05/19/2015 09:15:00 PM',
#   '016XX W DEVON AVE',
#   '1320',
#   'CRIMINAL DAMAGE',
#   'TO VEHICLE',
#   'STREET',
#   'false',
#   'false',
#   '2432',
#   '024',
#   '40',
#   '1',
#   '14',
#   '1164053',
#   '1942616',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.998165598',
#   '-87.671858058',
#   '"(41.998165598',
#   ' -87.671858058)"'],
#  ['10078577',
#   'HY267305',
#   '05/19/2015 09:14:00 PM',
#   '048XX S PRAIRIE AVE',
#   '1310',
#   'CRIMINAL DAMAGE',
#   'TO PROPERTY',
#   'APARTMENT',
#   'false',
#   'false',
#   '0224',
#   '002',
#   '3',
#   '38',
#   '14',
#   '1178900',
#   '1872936',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.806633097',
#   '-87.619374845',
#   '"(41.806633097',
#   ' -87.619374845)"'],
#  ['10078544',
#   'HY267309',
#   '05/19/2015 09:09:00 PM',
#   '077XX S ADA ST',
#   '4387',
#   'OTHER OFFENSE',
#   'VIOLATE ORDER OF PROTECTION',
#   'RESIDENCE',
#   'true',
#   'false',
#   '0612',
#   '006',
#   '17',
#   '71',
#   '26',
#   '1168744',
#   '1853474',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.753452465',
#   '-87.657184824',
#   '"(41.753452465',
#   ' -87.657184824)"'],
#  ['10078537',
#   'HY267299',
#   '05/19/2015 09:05:00 PM',
#   '018XX S DRAKE AVE',
#   '031A',
#   'ROBBERY',
#   'ARMED: HANDGUN',
#   'SIDEWALK',
#   'false',
#   'false',
#   '1021',
#   '010',
#   '24',
#   '29',
#   '03',
#   '1152958',
#   '1890717',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.855978408',
#   '-87.714051839',
#   '"(41.855978408',
#   ' -87.714051839)"'],
#  ['10078504',
#   'HY267273',
#   '05/19/2015 09:00:00 PM',
#   '0000X S HALSTED ST',
#   '0860',
#   'THEFT',
#   'RETAIL THEFT',
#   'GROCERY FOOD STORE',
#   'true',
#   'false',
#   '1232',
#   '012',
#   '27',
#   '28',
#   '06',
#   '1171024',
#   '1899834',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.880619441',
#   '-87.647473428',
#   '"(41.880619441',
#   ' -87.647473428)"'],
#  ['10079758',
#   'HY268159',
#   '05/19/2015 09:00:00 PM',
#   '078XX S MORGAN ST',
#   '0910',
#   'MOTOR VEHICLE THEFT',
#   'AUTOMOBILE',
#   'STREET',
#   'false',
#   'false',
#   '0612',
#   '006',
#   '17',
#   '71',
#   '07',
#   '1170959',
#   '1853037',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.752205224',
#   '-87.649080404',
#   '"(41.752205224',
#   ' -87.649080404)"'],
#  ['10078745',
#   'HY267507',
#   '05/19/2015 09:00:00 PM',
#   '020XX N KEYSTONE AVE',
#   '0820',
#   'THEFT',
#   '$500 AND UNDER',
#   'STREET',
#   'false',
#   'false',
#   '2525',
#   '025',
#   '30',
#   '20',
#   '06',
#   '1149088',
#   '1913399',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.918296002',
#   '-87.727669172',
#   '"(41.918296002',
#   ' -87.727669172)"'],
#  ['10078515',
#   'HY267289',
#   '05/19/2015 09:00:00 PM',
#   '0000X E ONTARIO ST',
#   '0890',
#   'THEFT',
#   'FROM BUILDING',
#   'RESTAURANT',
#   'false',
#   'false',
#   '1834',
#   '018',
#   '42',
#   '8',
#   '06',
#   '1176789',
#   '1904463',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.893193288',
#   '-87.626165013',
#   '"(41.893193288',
#   ' -87.626165013)"'],
#  ['10078587',
#   'HY267348',
#   '05/19/2015 08:58:00 PM',
#   '037XX S WENTWORTH AVE',
#   '143B',
#   'WEAPONS VIOLATION',
#   'UNLAWFUL POSS OTHER FIREARM',
#   'RESIDENCE',
#   'true',
#   'false',
#   '0915',
#   '009',
#   '3',
#   '34',
#   '15',
#   '1175518',
#   '1880310',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.826944441',
#   '-87.631557931',
#   '"(41.826944441',
#   ' -87.631557931)"'],
#  ['10078511',
#   'HY267259',
#   '05/19/2015 08:50:00 PM',
#   '050XX S MARSHFIELD AVE',
#   '041A',
#   'BATTERY',
#   'AGGRAVATED: HANDGUN',
#   'STREET',
#   'false',
#   'false',
#   '0931',
#   '009',
#   '16',
#   '61',
#   '04B',
#   '1166237',
#   '1871088',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.801841243',
#   '-87.665871066',
#   '"(41.801841243',
#   ' -87.665871066)"'],
#  ['10078463',
#   'HY267257',
#   '05/19/2015 08:48:00 PM',
#   '006XX N RIDGEWAY AVE',
#   '2027',
#   'NARCOTICS',
#   'POSS: CRACK',
#   'SIDEWALK',
#   'true',
#   'false',
#   '1122',
#   '011',
#   '27',
#   '23',
#   '18',
#   '1151239',
#   '1903806',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.891929929',
#   '-87.720018184',
#   '"(41.891929929',
#   ' -87.720018184)"'],
#  ['10078560',
#   'HY267278',
#   '05/19/2015 08:41:00 PM',
#   '030XX W 53RD PL',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'STREET',
#   'true',
#   'false',
#   '0923',
#   '009',
#   '14',
#   '63',
#   '18',
#   '1157184',
#   '1868972',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.796222764',
#   '-87.699129427',
#   '"(41.796222764',
#   ' -87.699129427)"'],
#  ['10078549',
#   'HY267252',
#   '05/19/2015 08:35:00 PM',
#   '036XX W 83RD PL',
#   '041A',
#   'BATTERY',
#   'AGGRAVATED: HANDGUN',
#   'STREET',
#   'false',
#   'false',
#   '0834',
#   '008',
#   '18',
#   '70',
#   '04B',
#   '1153376',
#   '1849005',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.741506403',
#   '-87.713621344',
#   '"(41.741506403',
#   ' -87.713621344)"'],
#  ['10079090',
#   'HY267787',
#   '05/19/2015 08:35:00 PM',
#   '068XX S DANTE AVE',
#   '1320',
#   'CRIMINAL DAMAGE',
#   'TO VEHICLE',
#   'STREET',
#   'false',
#   'false',
#   '0332',
#   '003',
#   '5',
#   '43',
#   '14',
#   '1187183',
#   '1859820',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.770448941',
#   '-87.589412208',
#   '"(41.770448941',
#   ' -87.589412208)"'],
#  ['10078567',
#   'HY267254',
#   '05/19/2015 08:34:00 PM',
#   '055XX W FULTON ST',
#   '041A',
#   'BATTERY',
#   'AGGRAVATED: HANDGUN',
#   'SIDEWALK',
#   'false',
#   'false',
#   '1523',
#   '015',
#   '28',
#   '25',
#   '04B',
#   '1139260',
#   '1901504',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.885839488',
#   '-87.764068418',
#   '"(41.885839488',
#   ' -87.764068418)"'],
#  ['10078518',
#   'HY267286',
#   '05/19/2015 08:30:00 PM',
#   '080XX S BURNHAM AVE',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'RESIDENCE',
#   'false',
#   'true',
#   '0422',
#   '004',
#   '7',
#   '46',
#   '08B',
#   '1196273',
#   '1852253',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.749463973',
#   '-87.556343089',
#   '"(41.749463973',
#   ' -87.556343089)"'],
#  ['10080685',
#   'HY268042',
#   '05/19/2015 08:30:00 PM',
#   '030XX E 92ND ST',
#   '0460',
#   'BATTERY',
#   'SIMPLE',
#   'STREET',
#   'false',
#   'false',
#   '0424',
#   '004',
#   '10',
#   '46',
#   '08B',
#   '1198290',
#   '1844587',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.728377667',
#   '-87.549208103',
#   '"(41.728377667',
#   ' -87.549208103)"'],
#  ['10078536',
#   'HY267351',
#   '05/19/2015 08:20:00 PM',
#   '051XX W MONTROSE AVE',
#   '1811',
#   'NARCOTICS',
#   'POSS: CANNABIS 30GMS OR LESS',
#   'ALLEY',
#   'true',
#   'false',
#   '1624',
#   '016',
#   '45',
#   '15',
#   '18',
#   '1141519',
#   '1928733',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.96051731',
#   '-87.755098524',
#   '"(41.96051731',
#   ' -87.755098524)"'],
#  ['10078538',
#   'HY267216',
#   '05/19/2015 08:19:00 PM',
#   '076XX S ABERDEEN ST',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'RESIDENCE',
#   'false',
#   'true',
#   '0612',
#   '006',
#   '17',
#   '71',
#   '08B',
#   '1170262',
#   '1854345',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.755809731',
#   '-87.65159662',
#   '"(41.755809731',
#   ' -87.65159662)"'],
#  ['10078495',
#   'HY267239',
#   '05/19/2015 08:18:00 PM',
#   '081XX S KINGSTON AVE',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'ALLEY',
#   'false',
#   'true',
#   '0422',
#   '004',
#   '7',
#   '46',
#   '08B',
#   '1194556',
#   '1851379',
#   '2015',
#   '05/26/2015 12:42:06 PM',
#   '41.747108022',
#   '-87.562663429',
#   '"(41.747108022',
#   ' -87.562663429)"']]

# %%
#select columns 11: district, 18: year
fields2 = fields.map(lambda f: (f[11], f[17]))
fields2.take(10)
# Out:
# [('006', '2015'),
#  ('024', '2015'),
#  ('004', '2015'),
#  ('003', '2015'),
#  ('009', '2015'),
#  ('010', '2015'),
#  ('007', '2015'),
#  ('014', '2015'),
#  ('011', '2015'),
#  ('008', '2015')]

# %%
#map to count each record once: (district, year), count(crime)
pairs = fields2.map(lambda x: (x[0] + ',' + x[1],1)) 
pairs.take(10)
# Out:
# [('006,2015', 1),
#  ('024,2015', 1),
#  ('004,2015', 1),
#  ('003,2015', 1),
#  ('009,2015', 1),
#  ('010,2015', 1),
#  ('007,2015', 1),
#  ('014,2015', 1),
#  ('011,2015', 1),
#  ('008,2015', 1)]

# %%
#reduceByKey to generate key, value pair: (district, year), count(crime)
counts = pairs.reduceByKey(lambda x,y: int(x) + int(y))
counts.take(10)
# Out:
# [('011,2013', 21279),
#  ('011,2001', 151),
#  ('006,2011', 19740),
#  ('010,2015', 3907),
#  ('010,2012', 14639),
#  ('017,2003', 7743),
#  ('004,2011', 20298),
#  ('017,2001', 53),
#  ('014,2009', 15194),
#  ('019,2015', 3573)]

# %%
#top10 = counts.map(lambda x: (x[1], x[0])).sortByKey(ascending = False).take(100)

# %%
#convert to RDD
#top10rdd =  sc.parallelize(top10)
#top10rdd.take(10)
# Out:
# [(30857, '008,2006'),
#  (29959, '008,2004'),
#  (29885, '008,2007'),
#  (29837, '008,2005'),
#  (29420, '008,2008'),
#  (28022, '011,2004'),
#  (27918, '011,2005'),
#  (27434, '007,2004'),
#  (27347, '008,2009'),
#  (27050, '011,2006')]

# %%
#map key,value pair back to district, year, count(crime)
#counts2 = counts.map(lambda x: (re.split(',', x[1]), x[0]))

counts2 = counts.map(lambda x: (x[0].split(',')[0], x[0].split(',')[1], x[1]))
counts2.count()
# Out:
# 347

# %%
counts2.take(10)
# Out:
# [('011', '2013', 21279),
#  ('011', '2001', 151),
#  ('006', '2011', 19740),
#  ('010', '2015', 3907),
#  ('010', '2012', 14639),
#  ('017', '2003', 7743),
#  ('004', '2011', 20298),
#  ('017', '2001', 53),
#  ('014', '2009', 15194),
#  ('019', '2015', 3573)]

# %%
#split into two RDD objects by year for Daly (2001 - 2010), Emanuel (2011 - 2015)
Daley = counts2.filter(lambda x: int(x[1])<=2010).map(lambda y: (y[0], y[2]))
Daley.take(10)
# Out:
# [('011', 151),
#  ('017', 7743),
#  ('017', 53),
#  ('014', 15194),
#  ('015', 19403),
#  ('019', 18987),
#  ('007', 26505),
#  ('018', 15542),
#  ('003', 19608),
#  ('022', 11763)]

# %%
Emanuel = counts2.filter(lambda x: int(x[1])>=2011).map(lambda y: (y[0], y[2]))
Emanuel.take(10)
# Out:
# [('011', 21279),
#  ('006', 19740),
#  ('010', 3907),
#  ('010', 14639),
#  ('004', 20298),
#  ('019', 3573),
#  ('010', 11948),
#  ('016', 3104),
#  ('004', 15859),
#  ('009', 14351)]

# %%
#key value pair of {district, count of crime}, return 26 pairs
#divide count of crime by number of years to get average annual number of crime
Daley2 = Daley.reduceByKey(lambda x,y: int(x) + int(y))
Daley2 = Daley2.map(lambda x: (x[0], int(x[1])/10))
Daley2.take(26)
# Out:
# [('017', 9022.9),
#  ('007', 19300.9),
#  ('005', 13758.8),
#  ('016', 10238.7),
#  ('014', 12517.1),
#  ('009', 15985.0),
#  ('024', 9719.6),
#  ('004', 17453.5),
#  ('002', 14313.9),
#  ('012', 15008.7),
#  ('031', 6.7),
#  ('022', 10089.3),
#  ('010', 13096.0),
#  ('018', 13292.2),
#  ('003', 16327.8),
#  ('008', 22027.2),
#  ('025', 18510.2),
#  ('023', 0.3),
#  ('019', 13833.0),
#  ('021', 0.4),
#  ('015', 14155.8),
#  ('001', 11561.3),
#  ('011', 19439.1),
#  ('020', 5383.3),
#  ('013', 0.1),
#  ('006', 18047.7)]

# %%
#key value pair of {district, count of crime}, return 24 pairs
Emanuel2 = Emanuel.reduceByKey(lambda x,y: int(x) + int(y))
Emanuel2 = Emanuel2.map(lambda x: (x[0], int(x[1])/5))
Emanuel2.take(24)
# Out:
# [('017', 7416.6),
#  ('007', 15609.8),
#  ('016', 8754.4),
#  ('005', 11760.0),
#  ('014', 9588.4),
#  ('009', 13162.4),
#  ('024', 7480.0),
#  ('004', 15586.0),
#  ('002', 10750.8),
#  ('012', 12057.0),
#  ('031', 10.6),
#  ('022', 8402.2),
#  ('010', 11648.4),
#  ('018', 11129.2),
#  ('003', 13669.4),
#  ('008', 17750.2),
#  ('025', 15450.4),
#  ('019', 11868.0),
#  ('015', 11833.6),
#  ('001', 9971.6),
#  ('011', 17947.2),
#  ('020', 4212.8),
#  ('013', 0.2),
#  ('006', 15499.0)]

# %%
#inner join Daley2 and Emanuel by district: {district, (Delay count, Emanuel count)}
joined = Daley2.join(Emanuel2)
joined.count()
# Out:
# 24

# %%
joined.take(24)
# Out:
# [('017', (9022.9, 7416.6)),
#  ('009', (15985.0, 13162.4)),
#  ('024', (9719.6, 7480.0)),
#  ('012', (15008.7, 12057.0)),
#  ('010', (13096.0, 11648.4)),
#  ('019', (13833.0, 11868.0)),
#  ('015', (14155.8, 11833.6)),
#  ('001', (11561.3, 9971.6)),
#  ('006', (18047.7, 15499.0)),
#  ('007', (19300.9, 15609.8)),
#  ('005', (13758.8, 11760.0)),
#  ('016', (10238.7, 8754.4)),
#  ('014', (12517.1, 9588.4)),
#  ('004', (17453.5, 15586.0)),
#  ('002', (14313.9, 10750.8)),
#  ('031', (6.7, 10.6)),
#  ('022', (10089.3, 8402.2)),
#  ('018', (13292.2, 11129.2)),
#  ('003', (16327.8, 13669.4)),
#  ('008', (22027.2, 17750.2)),
#  ('025', (18510.2, 15450.4)),
#  ('011', (19439.1, 17947.2)),
#  ('020', (5383.3, 4212.8)),
#  ('013', (0.1, 0.2))]

# %%
#map to get {district, Delay count - Emanuel count}
crime_diff_sample = joined.map(lambda x: (x[0], float(x[1][0])-float(x[1][1])))
crime_diff_sample.take(24)
# Out:
# [('017', 1606.2999999999993),
#  ('009', 2822.6000000000004),
#  ('024', 2239.6000000000004),
#  ('012', 2951.7000000000007),
#  ('010', 1447.6000000000004),
#  ('019', 1965.0),
#  ('015', 2322.199999999999),
#  ('001', 1589.699999999999),
#  ('006', 2548.7000000000007),
#  ('007', 3691.100000000002),
#  ('005', 1998.7999999999993),
#  ('016', 1484.300000000001),
#  ('014', 2928.7000000000007),
#  ('004', 1867.5),
#  ('002', 3563.1000000000004),
#  ('031', -3.8999999999999995),
#  ('022', 1687.0999999999985),
#  ('018', 2163.0),
#  ('003', 2658.3999999999996),
#  ('008', 4277.0),
#  ('025', 3059.800000000001),
#  ('011', 1491.8999999999978),
#  ('020', 1170.5),
#  ('013', -0.1)]

# %%
#calculate sample mean, sample standard deviation
#calculate t-statistics and perform 1-sided student-t test to test hypothesis null: (Delay count - Emanuel count) >0
#https://math.stackexchange.com/questions/1287990/estimating-population-standard-deviation-with-sample-standard-deviation
crime_diff_sample.persist()
mean = crime_diff_sample.map(lambda x: x[1]).mean()
sd = crime_diff_sample.map(lambda x: x[1]).stdev()
n = crime_diff_sample.map(lambda x: x[1]).count()

# %%
t = (mean-0)/(sd/math.sqrt(n))
t
# Out:
# 10.425179223281729

# %%
p_value = stats.t.sf(float(t), n-1)  # one-sided pvalue = Prob(mean>0)
p_value
# Out:
# 1.7323259949349822e-10

# %% [markdown]
# Here p_value is very small approximatedly zero.
# Hence, we reject the hypothesis and conclude that average amount of crime per year during Daley's office is statistically higher than that during Emanuel's office.
